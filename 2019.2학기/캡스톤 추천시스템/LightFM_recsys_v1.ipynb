# %% [markdown]
# ## Build Recommenders using LightFM
# - LightFM is a Python implementation of a number of popular recommendation algorithms for both implicit and explicit feedback.
# - It also makes it possible to incorporate both item and user metadata into the traditional matrix factorization algorithms.
# - It represents each user and item as the sum of the latent representations of their features, thus allowing recommendations to generalise to new items (via item features) and to new users (via user features).
# http://lyst.github.io/lightfm/docs/index.html

# %%
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from lightfm.data import Dataset
from lightfm.cross_validation import random_train_test_split

import pandas as pd
import numpy as np
from sklearn.externals import joblib
# Out:
# C:\Users\hyoun\Anaconda3\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %% [markdown]
# #### Read Data

# %%
# 백화점 보다 sparsity 정도가 상당히 심한 책 데이터를 이용하여 추천시스템 구축
transaction = pd.read_csv('book_transactions.csv', encoding='cp949').dropna(axis=0).query('ISBN != "-"')

# %%
transaction.head()
# Out:
#    회원번호        일자                             책제목      카테고리  \
# 0   292  20140621           유형아작 중학수학 3-2 (2014년)    중고등학습서
# 1   292  20140621  개념+유형 중등수학 3-2 실력향상 파워 (2014년)    중고등학습서
# 2   292  20140621          내신특강 중학 수학 3-2 (2014년)    중고등학습서
# 3   294  20140528           액셀 월드 (ACCEL WORLD) 1  만화/라이트노벨
# 4   294  20140528                신약 어떤 마술의 금서목록 2  만화/라이트노벨
#
#                                    작가            ISBN              출판사  \
# 0                            <김순우> 등저  9788964166178     비상교육(구 비유와상징)
# 1                            <박미정> 등저  9788966868674     비상교육(구 비유와상징)
# 2                            <김정우> 등저  9788937898334        미래엔(대한교과서)
# 3        <카와하라 레키> 저/<HIMA> 그림/<김완> 역  9788926321379             서울문화사
# 4  <카마치 카즈마> 저/<하이무라 키요타카> 그림/<김소연> 역  9788925292564   대원씨아이(단행)(대원키즈)
#
#          출판일자  주문시간  수량    배송지
# 0  20110801.0    23   1  서울특별시
# 1  20140301.0    23   1  서울특별시
# 2  20130530.0    23   1  서울특별시
# 3  20091110.0    20   1     충남
# 4  20120115.0    20   1     충남

# %%
# item feature를 추가히기 위해 ISBN 기준으로 책 정보를 생성
item_data = transaction.drop_duplicates('ISBN').iloc[:,[5,2,3,4,6,7]].sort_values(by='ISBN')
item_data['출판일자'] = item_data['출판일자'].astype('int') // 100
item_data
# Out:
#                   ISBN                                                책제목  \
# 160802  2000132000143                    에스콰이어 + 바자 (월간) : 6월 합본세트 [2014]
# 105532  2012112110201                                 개구쟁이 특공대 최신판 (전13권)
# 74697   2012112303251                      [아람] New sos 안전동화 [전12권] 무비펜별도
# 228744  2013021802251                       [가우스] 쿵쿵 살아숨쉬는 대륙의 공룡들 (전20권)
# 3968    2511481629003                         여성동아 B형 (여성월간) : 12월 [2013]
# 132150  2511865908007                   베리타스알파 고입·대입을 위한 고품격 교육 신문 (175호)
# 110592  2511894396004                                          유레카논술 339호
# 53877   2512000318002      Gentleman KOREA 젠틀맨 코리아 + 레몬아이 겨울호 : 2월 [2014]
# 147767  2512009421000                                     초등 독서 논술 1학년 세트
# 238103  2512009422007                                     초등 독서 논술 2학년 세트
# 164969  2512009425008                                     초등 독서 논술 3학년 세트
# 202528  2512009426005                                     초등 독서 논술 4학년 세트
# 238105  2512009427002                                     초등 독서 논술 5학년 세트
# 164970  2512009428009                                     초등 독서 논술 6학년 세트
# 51453   2512021254006                                          유레카논술 340호
# 51472   2512126346002                                          유레카논술 341호
# 16531   2512186248001                          ELLE 엘르 (여성월간) : 3월 [2014]
# 98715   2512193140008        Gentleman KOREA 젠틀맨 코리아 E형 (월간) : 5월 [2014년]
# 17107   2512206019000            HARPER'S BAZAAR 바자 C형 (여성월간) : 3월 [2014]
# 241504  2512221887004                          여성중앙 C형 (여성월간) : 6월 [2014]
# 51471   2512245963005                                          유레카논술 342호
# 212052  2512353741007                              판타지 알파벳 콜렉터 1,2 + 3 세트
# 204764  2512542351000                                          유레카논술 344호
# 175084  2512828134006                                          유레카논술 346호
# 200842  2512990924009   ELLE 엘르 + ELLE ACCESSORIES 엘르 악세사리 + ELLE DECO...
# 245928  2513118198005                                          유레카논술 347호
# 231584  2513217741003                        ESSEN 에쎈 D형 (월간) : 6월 [2014]
# 112347  2513272542003                   행복이 가득한 집 C형 특별판 (월간) : 6월 [2014]
# 126199  2513272647005       여성중앙 + Gentleman KOREA 젠틀맨 코리아 A형 : 6월 [2014]
# 9676    2513356731002   ELLE DECOR 엘르 데코 (계간) : 여름호 + LemonTree 레몬트리 :...
# ...                ...                                                ...
# 171831  9791195260904                                        달로 가는 제멋대로 펜
# 193490  9791195260911                                               정원 일기
# 115900  9791195261703                                              고려를 읽다
# 99116   9791195262601                       공인노무사 2차(2010∼2013년) 최신기출문제해설
# 51885   9791195262908                                   2015 황현필 한국사 필기노트
# 226947  9791195263820                                    격동하는 동북아, 한국의 책략
# 226946  9791195263851                                         김정은 이렇게 망한다
# 226944  9791195263875                                   섬의 반란 1948년 4월 3일
# 226945  9791195263899                                  리지웨이, 대한민국을 구한 지휘관
# 32889   9791195269112                                청소년이 꼭 알아야 할 과학이슈 11
# 114749  9791195270408                       Simply Bible 하나님나라 관점으로 읽는 성경
# 106510  9791195270804                                        남자답게 나이 드는 법
# 59893   9791195272402            매거진 그래픽노블 Graphic Novel (월간) : 6월 [2014]
# 82240   9791195275212                                         윤승현 초등교직 논술
# 183584  9791195275502                                               상실 수업
# 133601  9791195279609                                   아무도 가르쳐주지 않는 실전경매
# 185773  9791195280209                                 2015 대입 성공을 위한 모든 것
# 132923  9791195290710                         특목고 갈 사람 모여라 외고, 국제고, 자사고 편
# 75447   9791195293117                                         여자, 군주를 만나다
# 107926  9791195429523                                       오즈 GTQ 포토샵 2급
# 185853  9791195429578                                   컴퓨터로 배우는 재미있는 한국사
# 38289   9791195474226                                            성장 없는 번영
# 71976   9798934105786                                             골로새서 강해
# 166200  9798936441769                                         가만 있어도 웃는 눈
# 59450   9798972363292                                                바울신학
# 164746  9798985671919                                        한방처방의 구성과 적용
# 55169   9798990460768                                    근골격계의 기능해부 및 운동학
# 19074   9798991455589                                                 아가서
# 172415  9870899625229                                 오렌지 1kg 그리고 삶은 계속된다
# 17024   9878991310162                                         내 꿈에 국경은 없다
#
#            카테고리                                    작가                   출판사  \
# 160802       잡지                             가야미디어 편집부                 가야미디어
# 105532       전집                               유키노유미코외             꼬마대통령(전집)
# 74697        전집                                   편집부                아람(전집)
# 228744       전집                              한국가우스편집부             한국가우스(전집)
# 3968         잡지                            동아일보사편집부 편                 동아일보사
# 132150   중고등학습서                                 편집부 저                소년한국일보
# 110592   중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 53877        잡지                             중앙M&B 편집부                 중앙m&b
# 147767      어린이                                 편집부 저            YES24 기획상품
# 238103      어린이                                 편집부 저            YES24 기획상품
# 164969      어린이                                 편집부 저            YES24 기획상품
# 202528      어린이                                 편집부 저            YES24 기획상품
# 238105      어린이                                 편집부 저            YES24 기획상품
# 164970      어린이                                 편집부 저            YES24 기획상품
# 51453    중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 51472    중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 16531        잡지                             허스트중앙 편집부       HEARST JOONGANG
# 98715        잡지                                   편집부                 중앙m&b
# 17107        잡지                            가야미디어편집부 편                 가야미디어
# 241504       잡지                              중앙M&B편집부                 중앙m&b
# 51471    중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 212052      어린이                                 편집부 저                    겜툰
# 204764   중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 175084   중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 200842       잡지                                 편집부 편       HEARST JOONGANG
# 245928   중고등학습서                         <유레카논술 편집부> 저                유레카엠앤비
# 231584       잡지                           서울문화사 편집부 편                 서울문화사
# 112347       잡지                             디자인하우스편집부            디자인하우스(잡지)
# 126199       잡지                              중앙M&B편집부                 중앙m&b
# 9676         잡지                             중앙M&B 편집부                 중앙m&b
# ...         ...                                   ...                   ...
# 171831     국내문학                                <문훈> 저                  스윙밴드
# 193490     국내문학                               <이귀란> 저                  스윙밴드
# 115900       역사                               <이혜순> 저                    섬섬
# 99116   수험서 자격증                  <김기홍>,<이윤탁>,<전수환> 공저                   새흐름
# 51885   수험서 자격증                              <황현필> 편저                 윤앤준북스
# 226947    사회 정치                               <이춘근> 저                  백년동안
# 226946    사회 정치                               <김성욱> 저                  백년동안
# 226944    사회 정치                               <현길언> 저                  백년동안
# 226945    사회 정치                               <복거일> 저                  백년동안
# 32889       청소년                              <이충환> 등저        동아사이언스(과학동아북스)
# 114749       종교                               <신성관> 저                  베리타스
# 106510       인문                   <존 C.로빈슨> 저/<김정민> 역                  아날로그
# 59893        잡지                               피오니 편집부                   피오니
# 82240   수험서 자격증                               <윤승현> 저                   위드북
# 183584     해외문학  <엘리자베스 퀴블러 로스>,<데이비드 케슬러> 공저/<김소향> 역                  인빅투스
# 133601    경제 경영                               <이재균> 저                   파르마
# 185773   중고등학습서                        <한상희>,<장학수> 공저                   등용문
# 132923   중고등학습서                        <김종완>,<정영민> 공저                 더디퍼런스
# 75447      자기계발                               <안미헌> 저                  생각빌딩
# 107926   IT 모바일                          <웰북수험서개발팀> 저                    웰북
# 185853   IT 모바일                           <웰북교재연구회> 저                    웰북
# 38289     경제 경영                      <팀 잭슨> 저/<전광철> 역                 착한책가게
# 71976        종교                 <마틴 루이드 존스> 저/<강철성> 역              기독교문서선교회
# 166200      어린이                                   이미옥                    창비
# 59450        종교               <토마스 R. 슈라이너> 저/<엄성옥> 역               은성(은성사)
# 164746     대학교재                       <삼웅재> 저/<김양일> 역                  신일상사
# 55169      대학교재                 <Donald A. Neumann> 저                 정담미디어
# 19074        종교                     <잔느 귀용> 저/<박선규> 역                 순전한나드
# 172415      청소년          <로젤린느 모렐> 저/<장은경> 그림/<김동찬> 역                청어람주니어
# 17024       청소년                               <박희정> 저  이덴슬리벨(EAT&SLEEPWELL)
#
#           출판일자
# 160802  201406
# 105532  201401
# 74697   201412
# 228744  201101
# 3968    201310
# 132150  201401
# 110592  201401
# 53877   201210
# 147767  201402
# 238103  201402
# 164969  201402
# 202528  201402
# 238105  201402
# 164970  201402
# 51453   201402
# 51472   201402
# 16531   201402
# 98715   201404
# 17107   201402
# 241504  201406
# 51471   201403
# 212052  201403
# 204764  201404
# 175084  201405
# 200842  201404
# 245928  201405
# 231584  201406
# 112347  201405
# 126199  201405
# 9676    201406
# ...        ...
# 171831  201405
# 193490  201406
# 115900  201405
# 99116   201404
# 51885   201404
# 226947  201406
# 226946  201406
# 226944  201406
# 226945  201406
# 32889   201405
# 114749  201405
# 106510  201405
# 59893   201406
# 82240   201406
# 183584  201405
# 133601  201405
# 185773  201406
# 132923  201406
# 75447   201406
# 107926  201302
# 185853  201312
# 38289   201310
# 71976   199711
# 166200  200204
# 59450   200505
# 164746  200209
# 55169   200903
# 19074   201001
# 172415  200906
# 17024   200809
#
# [66001 rows x 6 columns]

# %%
# user feature를 추가히기 위해 회원번호 기준으로 고객 정보를 생성
user_data = transaction.drop_duplicates('회원번호').iloc[:,[0,-1]].sort_values(by='회원번호')
fclass = pd.qcut(transaction.groupby('회원번호')['수량'].sum(), 4, labels=False).reset_index().rename(columns={'수량': '구매등급'})
user_data = pd.merge(user_data, fclass)
user_data
# Out:
#         회원번호      배송지  구매등급
# 0        292    서울특별시     1
# 1        294       충남     1
# 2        299     경상북도     0
# 3        300    광주광역시     0
# 4        308     전라남도     2
# 5        310    대전광역시     0
# 6        315      경기도     1
# 7        316     전라북도     1
# 8        318    인천광역시     0
# 9        329     전라남도     1
# 10       332      경기도     1
# 11       335    서울특별시     0
# 12       340      경기도     0
# 13       344      경기도     0
# 14       345    대구광역시     0
# 15       348     경상남도     0
# 16       355       경남     3
# 17       357    대전광역시     1
# 18       360       울산     0
# 19       368    인천광역시     0
# 20       374    대전광역시     0
# 21       376      경기도     0
# 22       377      경기도     1
# 23       384      경기도     0
# 24       385    대전광역시     0
# 25       388     전라남도     0
# 26       392     경상북도     0
# 27       441       전북     0
# 28       442    인천광역시     0
# 29       443      경기도     1
# ...      ...      ...   ...
# 26577  99851    대구광역시     1
# 26578  99852       부산     3
# 26579  99854      경기도     3
# 26580  99855     경상남도     0
# 26581  99860      경기도     3
# 26582  99861    인천광역시     2
# 26583  99862     경상북도     2
# 26584  99865      경기도     2
# 26585  99866    대구광역시     1
# 26586  99868       서울     2
# 26587  99872    서울특별시     2
# 26588  99878     전라남도     3
# 26589  99879      경기도     0
# 26590  99880      경기도     2
# 26591  99882       서울     0
# 26592  99884      경기도     3
# 26593  99885    대전광역시     0
# 26594  99886    서울특별시     1
# 26595  99889      경기도     0
# 26596  99891    대전광역시     1
# 26597  99892    서울특별시     0
# 26598  99893      경기도     2
# 26599  99894    울산광역시     2
# 26600  99895    서울특별시     3
# 26601  99896  제주특별자치도     2
# 26602  99899      경기도     1
# 26603  99901    광주광역시     3
# 26604  99903      경기도     0
# 26605  99904    서울특별시     0
# 26606  99906    대구광역시     3
#
# [26607 rows x 3 columns]

# %%
joblib.dump((user_data, item_data), 'recsys_user_item.pkl')
# Out:
# ['recsys_user_item.pkl']

# %% [markdown]
# #### Transform Data

# %%
# user & item feature를 추가히기 위해 아래와 같은 형식으로 지정할 것!
user_info = (
    user_data['회원번호'],
    user_data['구매등급'],
    # ...
)

item_info = (
    item_data['ISBN'],
    item_data['카테고리'],
    item_data['출판일자'],
    # ...
)

# %%
def build_features(ftype, dataset, features):
    uf = []
    for r in range(len(features[0])):
        uf1 = []
        for c in range(1, len(features)):
            uf1.append(features[c].iloc[r])
        uf.append((features[0].iloc[r], uf1))        
    for c in range(1, len(features)):
        if ftype == 'user':
            dataset.fit_partial(users=features[0], user_features=features[c])
        else:
            dataset.fit_partial(items=features[0], item_features=features[c])       
    if ftype == 'user':
        return dataset.build_user_features(uf)
    else:
        return dataset.build_item_features(uf)

# %%
ds = Dataset()
# First, specify user_ids & item_ids
ds.fit(users=user_data['회원번호'], items=item_data['ISBN'])

# Second, build an interaction matrix (like ratings matrix)
interactions, weights = ds.build_interactions([(i,j) for i, j in zip(transaction['회원번호'], transaction['ISBN'])])

# Third, build user features & item features
user_features = build_features('user', ds, user_info)
item_features = build_features('item', ds, item_info)

# %% [markdown]
# #### Split Data

# %%
train, test = random_train_test_split(interactions, test_percentage=0.25, random_state=np.random.RandomState(123))

# %% [markdown]
# #### Build Recommender Models

# %%
m1 = LightFM(loss='warp', random_state=123)  # Refer to LightFM API
# %time m1.fit(train)
m2 = LightFM(loss='warp', random_state=123)  # Refer to LightFM API
# %time m2.fit(train, user_features=user_features, item_features=item_features)
# Out:
# Wall time: 725 ms
# Wall time: 1.15 s

# %% [markdown]
# #### Evaluate Recommender Models

# %%
# Compute precision, recall & f1-score
def precision_recall_score(model, data, user_features, item_features, k):
    precision = precision_at_k(model, data, user_features=user_features, item_features=item_features, k=k).mean()
    recall = recall_at_k(model, data, user_features=user_features, item_features=item_features, k=k).mean()
    f1_score = 2 * (precision * recall) / (precision + recall)
    return precision, recall, f1_score

# %time print(precision_recall_score(m1, test, user_features=None, item_features=None, k=10))
# %time print(precision_recall_score(m2, test, user_features=user_features, item_features=item_features, k=10))
# Out:
# (0.011190699, 0.03356963024769485, 0.01678574060404797)
# Wall time: 2min 4s
# (0.006551326, 0.02101328866299061, 0.009988523520619031)
# Wall time: 2min 39s

# %% [markdown]
# #### Recommend top-N Items

# %%
# Recommend top-N items for each user
def make_recommendation(model, dataset, user_features, item_features, n_users, k):
    n_items = dataset.interactions_shape()[1]
    recs = []
    for user_id in range(n_users):
        scores = model.predict(user_id, np.arange(n_items), user_features=user_features, item_features=item_features)
        top_items = np.argsort(-scores)[:k]      
        rec = [list(dataset.mapping()[2].keys())[i] for i in top_items]
        recs.append(rec)
    recs = pd.DataFrame(pd.DataFrame(recs, index=list(dataset.mapping()[0].keys())[:n_users]).stack()).reset_index(). \
                    rename({'level_0':'user_id', 'level_1': 'rank', 0: 'item_id'}, axis=1).iloc[:,[0,2,1]]
    return recs    

# %time make_recommendation(m2, ds, user_features=user_features, item_features=item_features, n_users=1000, k=10)
# Out:
# Wall time: 22.9 s
#       user_id         item_id  rank
# 0         292  9788937488351      0
# 1         292  9788956056852      1
# 2         292  9788970653976      2
# 3         292  9788965420170      3
# 4         292  9788917218336      4
# 5         292  9788952227829      5
# 6         292  9788965961055      6
# 7         292  9788949171197      7
# 8         292  9788991731783      8
# 9         292  9788954730631      9
# 10        294  9788937488351      0
# 11        294  9788956056852      1
# 12        294  9788970653976      2
# 13        294  9788965420170      3
# 14        294  9788917218336      4
# 15        294  9788952227829      5
# 16        294  9788965961055      6
# 17        294  9788991731783      7
# 18        294  9788949171197      8
# 19        294  9788954730631      9
# 20        299  9788965420170      0
# 21        299  9788956056852      1
# 22        299  9788937488351      2
# 23        299  9788917218336      3
# 24        299  9791156170150      4
# 25        299  9788970653976      5
# 26        299  9788991731783      6
# 27        299  9788917218343      7
# 28        299  9788960477957      8
# 29        299  9788965961055      9
# ...       ...             ...   ...
# 9970     6363  9788954730631      0
# 9971     6363  9788937488351      1
# 9972     6363  9788950952587      2
# 9973     6363  9788954731904      3
# 9974     6363  9788965673675      4
# 9975     6363  9788970653976      5
# 9976     6363  9788954731621      6
# 9977     6363  9788949171197      7
# 9978     6363  9788965961055      8
# 9979     6363  9788954730648      9
# 9980     6393  9788954730631      0
# 9981     6393  9788937488351      1
# 9982     6393  9788950952587      2
# 9983     6393  9788954731904      3
# 9984     6393  9788965673675      4
# 9985     6393  9788970653976      5
# 9986     6393  9788954731621      6
# 9987     6393  9788949171197      7
# 9988     6393  9788965961055      8
# 9989     6393  9788954730648      9
# 9990     6394  9788937488351      0
# 9991     6394  9788970653976      1
# 9992     6394  9788954730631      2
# 9993     6394  9788949171197      3
# 9994     6394  9788965961055      4
# 9995     6394  9788956056852      5
# 9996     6394  9788952227829      6
# 9997     6394  9788965744030      7
# 9998     6394  9788965744023      8
# 9999     6394  9788970127248      9
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## End
