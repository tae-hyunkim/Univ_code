# %% [markdown]
# ## Make Negative Samples

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import gc

# %%
USER, ITEM, RATING = '회원번호', 'ISBN', '평점'

# %%
ratings_df = pd.read_csv('book_transactions.csv', encoding='cp949').dropna(axis=0).query('ISBN != "-"')

# Add ratings column
ratings_df[RATING] = 1

ratings_df
# Out:
#          회원번호        일자                                 책제목       카테고리  \
# 0         292  20140621               유형아작 중학수학 3-2 (2014년)     중고등학습서
# 1         292  20140621      개념+유형 중등수학 3-2 실력향상 파워 (2014년)     중고등학습서
# 2         292  20140621              내신특강 중학 수학 3-2 (2014년)     중고등학습서
# 3         294  20140528               액셀 월드 (ACCEL WORLD) 1   만화/라이트노벨
# 4         294  20140528                    신약 어떤 마술의 금서목록 2   만화/라이트노벨
# 5         294  20140528                    신약 어떤 마술의 금서목록 1   만화/라이트노벨
# 6         299  20140519                        에몽의 영문법의 재발견     중고등학습서
# 7         299  20140519                         능률 VOCA 어원편     중고등학습서
# 8         300  20140518                             우아한 거짓말        청소년
# 11        308  20140512                              갈매기의 꿈        청소년
# 12        308  20140512                          콩지의 착한 베이킹      가정 살림
# 13        308  20140512                        트루먼 스쿨 악플 사건        청소년
# 14        308  20140512                          청소년의 법과 생활        청소년
# 15        308  20140512                               범죄 수학        청소년
# 16        308  20140512                          진짜 기본 베이킹책      가정 살림
# 17        308  20140512                           시간을 파는 상점        청소년
# 18        308  20140512                               파란 아이        청소년
# 19        308  20140512                            뭘 해도 괜찮아        청소년
# 22        310  20140511                        블리치 BLEACH 1   만화/라이트노벨
# 23        315  20140506  소설 마비노기 더 드라마 이리아 The Drama IRIA 下       국내문학
# 24        315  20140506  소설 마비노기 더 드라마 이리아 The Drama IRIA 上       국내문학
# 25        315  20140506                           판도라 하츠 21   만화/라이트노벨
# 26        316  20140502                                아크 6       국내문학
# 27        316  20140502                                아크 7       국내문학
# 28        316  20140502                                아크 9       국내문학
# 29        316  20140502                                아크 8       국내문학
# 30        316  20140502                               아크 10       국내문학
# 31        318  20140526                 2014년 필 ITQ 엑셀 2007     IT 모바일
# 32        329  20140416                  완자 중등사회 중3 (2014년)     중고등학습서
# 33        329  20140416                 오투 중등과학 3-1 (2014년)     중고등학습서
# ...       ...       ...                                 ...        ...
# 251129  99901  20140615                       조셉 머피 잠재의식의 힘       자기계발
# 251130  99901  20140622                         인문의 바다에 빠져라         인문
# 251131  99901  20140622                       동양고전의 바다에 빠져라         인문
# 251132  99901  20140622                          강신주의 다상담 1         인문
# 251133  99901  20140622                                 리추얼         인문
# 251134  99901  20140630                            이중톈 미학강의         인문
# 251135  99901  20140630                       지금이 나는 더 행복하다       국내문학
# 251136  99903  20140518                           커피 마스터클래스      가정 살림
# 251137  99904  20140410                      영어패턴 500 + 플러스  국어 외국어 사전
# 251138  99906  20140116   Let's go to the English World! 2B      초등학습서
# 251139  99906  20140116   Let's go to the English World! 5A      초등학습서
# 251140  99906  20140205   Let's go to the English World! 2B      초등학습서
# 251141  99906  20140205   Let's go to the English World! 4C      초등학습서
# 251142  99906  20140310   Let's go to the English World! 2C      초등학습서
# 251137                               <이광수>,<이수경> 공저  9788959942589
# 251138                                        편집부 저  9788942765454
# 251139                                        편집부 저  9788942765539
# 251140                                        편집부 저  9788942765454
# 251141                                        편집부 저  9788942765522
# 251142                                        편집부 저  9788942765461
# 251143                                        편집부 저  9788942765508
# 251144                                  <후지이 아사리> 저  9788960471733
# 251145                                        편집부 저  9788942765539
# 251146                                        편집부 저  9788942765546
# 251147                                        편집부 저  9788942765478
# 251148                                        편집부 저  9788942765447
# 251149                                        편집부 저  9788942765461
# 251150                                        편집부 저  9788942765478
# 251151                                        편집부 저  9788942765546
# 251152                                        편집부 저  9788942765508
# 251153                                        편집부 저  9788942765461
# 251154                                        편집부 저  9788942765546
# 251155                                        편집부 저  9788942765508
# 251156                                        편집부 저  9788942765539
# 251157                                        편집부 저  9788942765553
# 251158                                        편집부 저  9788942765478
#
#                     출판사        출판일자  주문시간  수량    배송지  평점
# 0         비상교육(구 비유와상징)  20110801.0    23   1  서울특별시   1
# 1         비상교육(구 비유와상징)  20140301.0    23   1  서울특별시   1
# 2            미래엔(대한교과서)  20130530.0    23   1  서울특별시   1
# 3                 서울문화사  20091110.0    20   1     충남   1
# 4       대원씨아이(단행)(대원키즈)  20120115.0    20   1     충남   1
# 5       대원씨아이(단행)(대원키즈)  20111011.0    20   1     충남   1
# 6                  쏠티북스  20090801.0     0   1   경상북도   1
# 7              능률교육(학습)  20130110.0     0   1   경상북도   1
# 8                    창비  20091120.0    22   1  광주광역시   1
# 11                현문미디어  20070907.0    23   1   전라남도   1
# 12                멘토프레스  20080623.0    23   1   전라남도   1
# 13                  미래인  20081219.0    23   1   전라남도   1
# 14                  법무부  20130301.0    23   1   전라남도   1
# 15         Gbrain(지브레인)  20100723.0    23   1   전라남도   1
# 16           레시피팩토리(단행)  20140325.0    23   1   전라남도   1
# 17                자음과모음  20120410.0    23   1   전라남도   1
# 18                   창비  20130510.0    23   1   전라남도   1
# 19                  사계절  20121015.0    23   1   전라남도   1
# 22                서울문화사  20020430.0    19   1  대전광역시   1
# 23           학산문화사(단행본)  20140410.0    16   1    경기도   1
# 24           학산문화사(단행본)  20140410.0    16   1    경기도   1
# 25                   대원  20140404.0    16   1    경기도   1
# 26                로크미디어  20081104.0    19   1   전라북도   1
# 27                로크미디어  20081129.0    19   1   전라북도   1
# 28                로크미디어  20090130.0    19   1   전라북도   1
# 29                로크미디어  20090102.0    19   1   전라북도   1
# 30                로크미디어  20090226.0    19   1   전라북도   1
# 31              아카데미소프트  20130901.0    22   1  인천광역시   1
# 32        비상교육(구 비유와상징)  20111201.0    20   1   전라남도   1
# 33        비상교육(구 비유와상징)  20130901.0    20   1   전라남도   1
# ...                 ...         ...   ...  ..    ...  ..
# 251129             미래지식  20110415.0    12   1     광주   1
# 251130            스마트북스  20121025.0    13   1     광주   1
# 251131            스마트북스  20130330.0    13   1     광주   1
# 251132               동녘  20130731.0    13   1     광주   1
# 251133           책읽는수요일  20140126.0    13   1     광주   1
# 251134              김영사  20090130.0    17   1  서울특별시   1
# 251135          책으로여는세상  20131023.0    17   1  서울특별시   1
# 251136            북하우스엔  20110720.0    21   1    경기도   1
# 251137              넥서스  20120425.0     7   1  서울특별시   1
# 251138         천재교육(학원)  20080117.0    12   1  대구광역시   1
# 251139         천재교육(학원)  20080117.0    12   1  대구광역시   1
# 251140         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251141         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251142         천재교육(학원)  20080117.0    15   1  대구광역시   1
# 251143         천재교육(학원)  20080117.0    15   1  대구광역시   1
# 251144            길벗이지톡  20090620.0    15   1  대구광역시   1
# 251145         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251146         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251147         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251148         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251149         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251150         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251151         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251152         천재교육(학원)  20080117.0    13   1  대구광역시   1
# 251153         천재교육(학원)  20080117.0    22   1  대구광역시   1
# 251154         천재교육(학원)  20080117.0    22   1  대구광역시   1
# 251155         천재교육(학원)  20080117.0    16   2  대구광역시   1
# 251156         천재교육(학원)  20080117.0    15   1  대구광역시   1
# 251157         천재교육(학원)  20080117.0    15   1  대구광역시   1
# 251158         천재교육(학원)  20080117.0    15   1  대구광역시   1
#
# [242767 rows x 12 columns]

# %%
# random split using scikit-learn
train_valid_df, test_df, _, _ = train_test_split(ratings_df, ratings_df[RATING], test_size=0.3, random_state=0)

del ratings_df
gc.collect()
# Out:
# 0

# %%
# Sample n_neg negative items per positive item

import random
def negative_sampling(data, n_neg):
    item_pool = set(data[ITEM].unique())
    interact_status = (
        data.groupby(USER)[ITEM]
        .apply(set)
        .reset_index()
        .rename(columns={ITEM: ITEM + "_interacted"})
    )
    interact_status[ITEM + "_negative"] = interact_status[ITEM + "_interacted"].apply(lambda x: item_pool - x)

    users, items, ratings = [], [], []
    data = pd.merge(data, interact_status[[USER, ITEM + "_negative"]], on=USER)
    try:
        data[ITEM + "_negative"] = data[ITEM + "_negative"].apply(lambda x: random.sample(x, n_neg))
    except:
        min_num = min(map(len, list(data[ITEM + "_negative"])))
        data[ITEM + "_negative"] = data[ITEM + "_negative"].apply(lambda x: random.sample(x, min_num))
    for row in data.itertuples():
        users.append(getattr(row, USER))
        items.append(getattr(row, ITEM))
        ratings.append(float(getattr(row, RATING)))
        for i in getattr(row, ITEM + "_negative"):
            users.append(getattr(row, USER))
            items.append(i)
            ratings.append(float(0))
    return pd.DataFrame({USER: users, ITEM: items, RATING: ratings})

# %%
# Generate negative samples for only train data
train_valid_df = negative_sampling(train_valid_df, 1)
train_valid_df

# %%
# Save train & test data
from sklearn.externals import joblib 
joblib.dump((train_valid_df, test_df.loc[:,[USER, ITEM, RATING]]), 'recsys_train_test_1v1.pkl')

# For reading
#train_valid_df, test_df = joblib.load('recsys_train_test.pkl')

# %% [markdown]
# ## End
